# %%
# Listing 3.13
import os
from tavily import TavilyClient
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
tavily_client = TavilyClient(os.getenv("TAVILY_API_KEY"))

# %%
def search_web(query: str) -> str:
    """Search the web for the given query."""
    response = tavily_client.search(query, max_results=2, chunks_per_source=2)
    return response.get("results")

# %%
# Listing 3.14
results = search_web("Kipchoge's marathon world record")

# Format and display the results
print("=" * 80)
print("SEARCH RESULTS: Kipchoge's Marathon World Record")
print("=" * 80)

for i, result in enumerate(results, 1):
    print(f"\n📄 Result {i}:")
    print(f"   Title: {result.get('title', 'N/A')}")
    print(f"   URL: {result.get('url', 'N/A')}")
    print(f"   Score: {result.get('score', 'N/A')}")
    print(f"\n   Content:")
    print(f"   {result.get('content', 'N/A')}")
    print("\n" + "-" * 80)
# Out:
# ================================================================================
# SEARCH RESULTS: Kipchoge's Marathon World Record
# ================================================================================
#
# 📄 Result 1:
#    Title: Eliud Kipchoge reacts to Kelvin Kiptum's marathon world record
#    URL: https://www.olympics.com/en/news/eliud-kipchoge-reacts-kelvin-kiptum-marathon-world-record
#    Score: 0.9995956
#
#    Content:
#    # Eliud Kipchoge reacts to Kelvin Kiptum's marathon world record: "I was not surprised, and happy to see the record broken". The double Olympic champion, who is also a two-time world record holder, was the fastest man ever over the 42.2km (26.2 mile) marathon distance. "I was not surprised about [Kiptum] breaking the world record,” Kipchoge told a press conference on Friday, 20 October, in Oviedo, Asturias. Kipchoge, who last September became the **first man to win the Berlin Marathon for a record fifth time,** reiterated his focus for now ahead of the Olympic year in Paris. ## Elud Kipchoge on Kelvin Kiptum's world record: 'The beauty of sport is breaking records'. In fact, the new world record, **set by Kiptum in only his third marathon,** may have revived Kipchoge’s sub two-hour barrier dream. “I am still hungry of running fast,” he says of his future marathon plans that could include lining up against the new world record holder, potentially at Paris 2024.
#
# --------------------------------------------------------------------------------
#
# 📄 Result 2:
#    Title: Eliud Kipchoge Marathon World Record 2022 - YouTube
#    URL: https://www.youtube.com/watch?v=hxDn4EEMank
#    Score: 0.99938333
#
#    Content:
#    Eliud Kipchoge Marathon World Record 2022 - Finish of the BMW BERLIN MARATHON
# BMW BERLIN-MARATHON
# 17800 subscribers
# 22208 likes
# 2043427 views
# 25 Sep 2022
# Eliud Kipchoge finishs with a new world record that will be remembered forever.
# The greatest marathon runner of all times.
# #berlinmarathon #berlinlegend #worldrecord
# 1131 comments
#
#
# --------------------------------------------------------------------------------
